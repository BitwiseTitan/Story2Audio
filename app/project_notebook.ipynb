# %%
pip install gradio
# Out:
# ...
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# ...
#    ---------------------------------------- 0.0/54.1 MB ? eta -:--:--
#     --------------------------------------- 1.0/54.1 MB 8.5 MB/s eta 0:00:07
#    -- ------------------------------------- 3.7/54.1 MB 10.9 MB/s eta 0:00:05
#    ---- ----------------------------------- 6.3/54.1 MB 11.4 MB/s eta 0:00:05
#    ------ --------------------------------- 8.7/54.1 MB 11.4 MB/s eta 0:00:04
#    -------- ------------------------------- 11.0/54.1 MB 11.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 13.6/54.1 MB 11.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 16.0/54.1 MB 11.7 MB/s eta 0:00:04
#    ------------- -------------------------- 18.6/54.1 MB 11.6 MB/s eta 0:00:04
#    --------------- ------------------------ 21.2/54.1 MB 11.7 MB/s eta 0:00:03
# ...
